# %%
import sys
# !{sys.executable} -m pip install geopandas
# Out:
# Collecting geopandas
#   Downloading geopandas-0.9.0-py2.py3-none-any.whl (994 kB)
#      |████████████████████████████████| 994 kB 4.9 MB/s eta 0:00:01
# Collecting pyproj>=2.2.0
#   Downloading pyproj-3.2.1-cp37-cp37m-manylinux2010_x86_64.whl (6.3 MB)
#      |████████████████████████████████| 6.3 MB 77.9 MB/s eta 0:00:01
# Requirement already satisfied: shapely>=1.6 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from geopandas) (1.7.1)
# Requirement already satisfied: pandas>=0.24.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from geopandas) (1.3.2)
# Collecting fiona>=1.8
#   Downloading Fiona-1.8.20-cp37-cp37m-manylinux1_x86_64.whl (15.4 MB)
#      |████████████████████████████████| 15.4 MB 69.3 MB/s eta 0:00:01
# Collecting munch
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: six>=1.7 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from fiona>=1.8->geopandas) (1.16.0)
# Requirement already satisfied: click>=4.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from fiona>=1.8->geopandas) (8.0.1)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Collecting click-plugins>=1.0
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: attrs>=17 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from fiona>=1.8->geopandas) (21.2.0)
# Requirement already satisfied: setuptools in /srv/conda/envs/notebook/lib/python3.7/site-packages (from fiona>=1.8->geopandas) (49.6.0.post20210108)
# Requirement already satisfied: certifi in /srv/conda/envs/notebook/lib/python3.7/site-packages (from fiona>=1.8->geopandas) (2021.5.30)
# Requirement already satisfied: importlib-metadata in /srv/conda/envs/notebook/lib/python3.7/site-packages (from click>=4.0->fiona>=1.8->geopandas) (4.6.3)
# Requirement already satisfied: numpy>=1.17.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas>=0.24.0->geopandas) (1.21.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas>=0.24.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas>=0.24.0->geopandas) (2021.1)
# Requirement already satisfied: zipp>=0.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from importlib-metadata->click>=4.0->fiona>=1.8->geopandas) (3.5.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from importlib-metadata->click>=4.0->fiona>=1.8->geopandas) (3.10.0.0)
# Installing collected packages: munch, cligj, click-plugins, pyproj, fiona, geopandas
# Successfully installed click-plugins-1.1.1 cligj-0.7.2 fiona-1.8.20 geopandas-0.9.0 munch-2.5.0 pyproj-3.2.1

# %% [markdown]
# For more information about mapclassify see https://pysal.org/mapclassify/api.html

# %%
import sys
# !{sys.executable} -m pip install mapclassify
# Out:
# Collecting mapclassify
#   Downloading mapclassify-2.4.3-py3-none-any.whl (38 kB)
# Requirement already satisfied: networkx in /srv/conda/envs/notebook/lib/python3.7/site-packages (from mapclassify) (2.6.2)
# Requirement already satisfied: numpy>=1.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from mapclassify) (1.21.2)
# Requirement already satisfied: pandas>=1.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from mapclassify) (1.3.2)
# Requirement already satisfied: scipy>=1.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from mapclassify) (1.7.1)
# Requirement already satisfied: scikit-learn in /srv/conda/envs/notebook/lib/python3.7/site-packages (from mapclassify) (0.21.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas>=1.0->mapclassify) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas>=1.0->mapclassify) (2021.1)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas>=1.0->mapclassify) (1.16.0)
# Requirement already satisfied: joblib>=0.11 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from scikit-learn->mapclassify) (1.0.1)
# Installing collected packages: mapclassify
# Successfully installed mapclassify-2.4.3

# %%
import sys
# !{sys.executable} -m pip install libpysal
# Out:
# Collecting libpysal
#   Downloading libpysal-4.5.1-py3-none-any.whl (2.4 MB)
#      |████████████████████████████████| 2.4 MB 4.6 MB/s eta 0:00:01
# Requirement already satisfied: jinja2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from libpysal) (3.0.1)
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.10.0-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 10.6 MB/s eta 0:00:01
# Requirement already satisfied: requests in /srv/conda/envs/notebook/lib/python3.7/site-packages (from libpysal) (2.26.0)
# Requirement already satisfied: numpy>=1.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from libpysal) (1.21.2)
# Requirement already satisfied: scipy>=0.11 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from libpysal) (1.7.1)
# Requirement already satisfied: pandas in /srv/conda/envs/notebook/lib/python3.7/site-packages (from libpysal) (1.3.2)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.2.1-py3-none-any.whl (33 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jinja2->libpysal) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas->libpysal) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas->libpysal) (2021.1)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas->libpysal) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests->libpysal) (2021.5.30)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests->libpysal) (3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests->libpysal) (1.26.6)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests->libpysal) (2.0.0)
# Installing collected packages: soupsieve, beautifulsoup4, libpysal
# Successfully installed beautifulsoup4-4.10.0 libpysal-4.5.1 soupsieve-2.2.1

# %%
import geopandas as gpd
import pandas as pd

# %%
from geopandas import read_file
import mapclassify
mapclassify.__version__
# Out:
# '2.4.3'

# %%
import libpysal
libpysal.__version__
# Out:
# '4.5.1'

# %%
libpysal.examples.available()
# Out:
# Downloading AirBnB to /home/jovyan/pysal_data/AirBnB
# Downloading Atlanta to /home/jovyan/pysal_data/Atlanta
# Downloading Baltimore to /home/jovyan/pysal_data/Baltimore
# Downloading Bostonhsg to /home/jovyan/pysal_data/Bostonhsg
# Downloading Buenosaires to /home/jovyan/pysal_data/Buenosaires
# Downloading Charleston1 to /home/jovyan/pysal_data/Charleston1
# Downloading Charleston2 to /home/jovyan/pysal_data/Charleston2
# Downloading Chicago Health to /home/jovyan/pysal_data/Chicago_Health
# Downloading Chicago commpop to /home/jovyan/pysal_data/Chicago_commpop
# Example not downloaded: Chicago parcels
# Downloading Chile Labor to /home/jovyan/pysal_data/Chile_Labor
# Example not downloaded: Chile Migration
# Downloading Cincinnati to /home/jovyan/pysal_data/Cincinnati
# Downloading Cleveland to /home/jovyan/pysal_data/Cleveland
# Downloading Columbus to /home/jovyan/pysal_data/Columbus
# Downloading Elections to /home/jovyan/pysal_data/Elections
# Downloading Grid100 to /home/jovyan/pysal_data/Grid100
# Downloading Groceries to /home/jovyan/pysal_data/Groceries
# Downloading Guerry to /home/jovyan/pysal_data/Guerry
# Downloading Health Indicators to /home/jovyan/pysal_data/Health_Indicators
# Downloading Health+ to /home/jovyan/pysal_data/Health+
# Downloading Hickory1 to /home/jovyan/pysal_data/Hickory1
# Downloading Hickory2 to /home/jovyan/pysal_data/Hickory2
# Downloading Home Sales to /home/jovyan/pysal_data/Home_Sales
# Downloading Houston to /home/jovyan/pysal_data/Houston
# Downloading Juvenile to /home/jovyan/pysal_data/Juvenile
# Downloading Lansing1 to /home/jovyan/pysal_data/Lansing1
# Downloading Lansing2 to /home/jovyan/pysal_data/Lansing2
# Downloading Laozone to /home/jovyan/pysal_data/Laozone
# Downloading LasRosas to /home/jovyan/pysal_data/LasRosas
# Downloading Liquor Stores to /home/jovyan/pysal_data/Liquor_Stores
# Downloading Malaria to /home/jovyan/pysal_data/Malaria
# Downloading Milwaukee1 to /home/jovyan/pysal_data/Milwaukee1
# Downloading Milwaukee2 to /home/jovyan/pysal_data/Milwaukee2
# Downloading NCOVR to /home/jovyan/pysal_data/NCOVR
# Downloading NDVI to /home/jovyan/pysal_data/NDVI
# Downloading NYC to /home/jovyan/pysal_data/NYC
# Downloading NYC Earnings to /home/jovyan/pysal_data/NYC_Earnings
# Downloading NYC Education to /home/jovyan/pysal_data/NYC_Education
# Downloading NYC Neighborhoods to /home/jovyan/pysal_data/NYC_Neighborhoods
# Downloading NYC Socio-Demographics to /home/jovyan/pysal_data/NYC_Socio-Demographics
# Downloading Natregimes to /home/jovyan/pysal_data/Natregimes
# Downloading Nepal to /home/jovyan/pysal_data/Nepal
# Downloading Ohiolung to /home/jovyan/pysal_data/Ohiolung
# Downloading Orlando1 to /home/jovyan/pysal_data/Orlando1
# Downloading Orlando2 to /home/jovyan/pysal_data/Orlando2
# Downloading Oz9799 to /home/jovyan/pysal_data/Oz9799
# Downloading Phoenix ACS to /home/jovyan/pysal_data/Phoenix_ACS
# Downloading Pittsburgh to /home/jovyan/pysal_data/Pittsburgh
# Downloading Police to /home/jovyan/pysal_data/Police
# Downloading Rio Grande do Sul to /home/jovyan/pysal_data/Rio_Grande_do_Sul
# Downloading SIDS to /home/jovyan/pysal_data/SIDS
# Downloading SIDS2 to /home/jovyan/pysal_data/SIDS2
# Downloading Sacramento1 to /home/jovyan/pysal_data/Sacramento1
# Downloading Sacramento2 to /home/jovyan/pysal_data/Sacramento2
# Downloading SanFran Crime to /home/jovyan/pysal_data/SanFran_Crime
# Downloading Savannah1 to /home/jovyan/pysal_data/Savannah1
# Downloading Savannah2 to /home/jovyan/pysal_data/Savannah2
# Downloading Scotlip to /home/jovyan/pysal_data/Scotlip
# Downloading Seattle1 to /home/jovyan/pysal_data/Seattle1
# Downloading Seattle2 to /home/jovyan/pysal_data/Seattle2
# Downloading Snow to /home/jovyan/pysal_data/Snow
# Downloading South to /home/jovyan/pysal_data/South
# Example not downloaded: Spirals
# Downloading StLouis to /home/jovyan/pysal_data/StLouis
# Downloading Tampa1 to /home/jovyan/pysal_data/Tampa1
# Downloading US SDOH to /home/jovyan/pysal_data/US_SDOH
# Downloading clearwater to /home/jovyan/pysal_data/clearwater
# Downloading newHaven to /home/jovyan/pysal_data/newHaven
# Downloading nyc_bikes to /home/jovyan/pysal_data/nyc_bikes
# Downloading taz to /home/jovyan/pysal_data/taz
#          Name                                        Description  Installed
# 0       10740  Albuquerque, New Mexico, Census 2000 Tract Dat...       True
# 1      AirBnB  Airbnb rentals, socioeconomics, and crime in C...       True
# 2     Atlanta       Atlanta, GA region homicide counts and rates       True
# 3   Baltimore          Baltimore house sales prices and hedonics       True
# 4   Bostonhsg               Boston housing and neighborhood data       True
# ..        ...                                                ...        ...
# 93        taz           Traffic Analysis Zones in So. California       True
# 94      tokyo                               Tokyo Mortality data       True
# 95  us_income  Per-capita income for the lower 48 US states 1...       True
# 96   virginia                        Virginia counties shapefile       True
# 97       wmat          Datasets used for spatial weights testing       True
#
# [98 rows x 3 columns]

# %% [markdown]
# There are a number of examples. You can find a comprehensive list https://pysal.org/notebooks/lib/libpysal/Example_Datasets.html

# %%
_ = libpysal.examples.load_example('South')
pth = libpysal.examples.get_path('south.shp')

# %%
from libpysal.examples import explain

# %%
explain('South')
# Out:
#         <iframe
#             width="700"
#             height="350"
#             src="https://geodacenter.github.io/data-and-lab//south/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
_.get_file_list()
# Out:
# ['/home/jovyan/pysal_data/South/__MACOSX/._south',
#  '/home/jovyan/pysal_data/South/__MACOSX/south/._codebook.pdf',
#  '/home/jovyan/pysal_data/South/__MACOSX/south/._.DS_Store',
#  '/home/jovyan/pysal_data/South/__MACOSX/south/._south.html',
#  '/home/jovyan/pysal_data/South/south/south.mif',
#  '/home/jovyan/pysal_data/South/south/south.dbf',
#  '/home/jovyan/pysal_data/South/south/south.gpkg',
#  '/home/jovyan/pysal_data/South/south/south.gdb/a00000001.TablesByName.atx',
#  '/home/jovyan/pysal_data/South/south/south.gdb/a00000005.gdbtablx',
#  '/home/jovyan/pysal_data/South/south/south.gdb/a00000002.gdbtable',
#  '/home/jovyan/pysal_data/South/south/south.gdb/gdb',
#  '/home/jovyan/pysal_data/South/south/south.gdb/a00000005.CatItemTypesByUUID.atx',
#  '/home/jovyan/pysal_data/South/south/south.gdb/a00000003.gdbtablx',
#  '/home/jovyan/pysal_data/South/south/south.gdb/a00000003.gdbindexes',
#  '/home/jovyan/pysal_data/South/south/south.gdb/a00000009.gdbindexes',
#  '/home/jovyan/pysal_data/South/south/south.gdb/a00000002.gdbtablx',
#  '/home/jovyan/pysal_data/South/south/south.gdb/timestamps',
#  '/home/jovyan/pysal_data/South/south/south.gdb/a00000009.gdbtablx',
#  '/home/jovyan/pysal_data/South/south/south.gdb/a00000006.FDO_UUID.atx',
#  '/home/jovyan/pysal_data/South/south/south.gdb/a00000007.CatRelTypesByForwardLabel.atx',
#  '/home/jovyan/pysal_data/South/south/south.gdb/a00000007.CatRelTypesByBackwardLabel.atx',
#  '/home/jovyan/pysal_data/South/south/south.gdb/a00000006.gdbtable',
#  '/home/jovyan/pysal_data/South/south/south.gdb/a00000001.gdbindexes',
#  '/home/jovyan/pysal_data/South/south/south.gdb/a00000006.CatRelsByType.atx',
#  '/home/jovyan/pysal_data/South/south/south.gdb/a00000003.gdbtable',
#  '/home/jovyan/pysal_data/South/south/south.gdb/a00000004.CatItemsByType.atx',
#  '/home/jovyan/pysal_data/South/south/south.gdb/a00000006.CatRelsByOriginID.atx',
#  '/home/jovyan/pysal_data/South/south/south.gdb/a00000005.gdbindexes',
#  '/home/jovyan/pysal_data/South/south/south.gdb/a00000007.CatRelTypesByDestItemTypeID.atx',
#  '/home/jovyan/pysal_data/South/south/south.gdb/a00000007.CatRelTypesByOriginItemTypeID.atx',
#  '/home/jovyan/pysal_data/South/south/south.gdb/a00000007.gdbtablx',
#  '/home/jovyan/pysal_data/South/south/south.gdb/a00000007.gdbtable',
#  '/home/jovyan/pysal_data/South/south/south.gdb/a00000005.CatItemTypesByName.atx',
#  '/home/jovyan/pysal_data/South/south/south.gdb/a00000005.gdbtable',
#  '/home/jovyan/pysal_data/South/south/south.gdb/a00000004.spx',
#  '/home/jovyan/pysal_data/South/south/south.gdb/a00000005.CatItemTypesByParentTypeID.atx',
#  '/home/jovyan/pysal_data/South/south/south.gdb/a00000009.spx',
#  '/home/jovyan/pysal_data/South/south/south.gdb/a00000001.gdbtablx',
#  '/home/jovyan/pysal_data/South/south/south.gdb/a00000009.gdbtable',
#  '/home/jovyan/pysal_data/South/south/south.gdb/a00000004.gdbindexes',
#  '/home/jovyan/pysal_data/South/south/south.gdb/a00000001.gdbtable',
#  '/home/jovyan/pysal_data/South/south/south.gdb/a00000007.gdbindexes',
#  '/home/jovyan/pysal_data/South/south/south.gdb/a00000004.CatItemsByPhysicalName.atx',
#  '/home/jovyan/pysal_data/South/south/south.gdb/a00000004.gdbtable',
#  '/home/jovyan/pysal_data/South/south/south.gdb/a00000004.FDO_UUID.atx',
#  '/home/jovyan/pysal_data/South/south/south.gdb/a00000007.CatRelTypesByName.atx',
#  '/home/jovyan/pysal_data/South/south/south.gdb/a00000007.CatRelTypesByUUID.atx',
#  '/home/jovyan/pysal_data/South/south/south.gdb/a00000006.gdbtablx',
#  '/home/jovyan/pysal_data/South/south/south.gdb/a00000006.gdbindexes',
#  '/home/jovyan/pysal_data/South/south/south.gdb/a00000004.gdbtablx',
#  '/home/jovyan/pysal_data/South/south/south.gdb/a00000006.CatRelsByDestinationID.atx',
#  '/home/jovyan/pysal_data/South/south/south.html',
#  '/home/jovyan/pysal_data/South/south/south.mid',
#  '/home/jovyan/pysal_data/South/south/south.xlsx',
#  '/home/jovyan/pysal_data/South/south/south.shx',
#  '/home/jovyan/pysal_data/South/south/south.prj',
#  '/home/jovyan/pysal_data/South/south/south.csv',
#  '/home/jovyan/pysal_data/South/south/south.kml',
#  '/home/jovyan/pysal_data/South/south/south.geojson',
#  '/home/jovyan/pysal_data/South/south/.DS_Store',
#  '/home/jovyan/pysal_data/South/south/south.shp',
#  '/home/jovyan/pysal_data/South/south/south.sqlite',
#  '/home/jovyan/pysal_data/South/south/codebook.pdf']

# %%
df = read_file(pth)

# %%
South_tf= gpd.read_file(_.get_path('south.shp'))

# %%
df.head()
# Out:
#          NAME     STATE_NAME STATE_FIPS CNTY_FIPS   FIPS  STFIPS  COFIPS  \
# 0     Hancock  West Virginia         54       029  54029      54      29
# 1      Brooke  West Virginia         54       009  54009      54       9
# 2        Ohio  West Virginia         54       069  54069      54      69
# 3    Marshall  West Virginia         54       051  54051      54      51
# 4  New Castle       Delaware         10       003  10003      10       3
#
#    FIPSNO  SOUTH      HR60  ...      BLK90      GI59      GI69      GI79  \
# 0   54029      1  1.682864  ...   2.557262  0.223645  0.295377  0.332251
# 1   54009      1  4.607233  ...   0.748370  0.220407  0.318453  0.314165
# 2   54069      1  0.974132  ...   3.310334  0.272398  0.358454  0.376963
# 3   54051      1  0.876248  ...   0.546097  0.227647  0.319580  0.320953
# 4   10003      1  4.228385  ...  16.480294  0.256106  0.329678  0.365830
#
#        GI89       FH60  FH70       FH80       FH90  \
# 0  0.363934   9.981297   7.8   9.785797  12.604552
# 1  0.350569  10.929337   8.0  10.214990  11.242293
# 2  0.390534  15.621643  12.9  14.716681  17.574021
# 3  0.377346  11.962834   8.8   8.803253  13.564159
# 4  0.332703  12.035714  10.7  15.169480  16.380903
#
#                                             geometry
# 0  POLYGON ((-80.62805 40.39816, -80.60204 40.480...
# 1  POLYGON ((-80.52625 40.16245, -80.58760 40.175...
# 2  POLYGON ((-80.52517 40.02275, -80.73843 40.035...
# 3  POLYGON ((-80.52447 39.72113, -80.83248 39.718...
# 4  POLYGON ((-75.77270 39.38301, -75.79144 39.723...
#
# [5 rows x 70 columns]

# %%
# %matplotlib inline
South_tf.plot()

# %% [markdown]
# Visualize the Map of HR90 attribute [homicide rate per 100,000 (1960, 1970, 1980, 1990)] see details at https://www.rdocumentation.org/packages/spsur/versions/1.0.0.4/topics/NCOVR

# %%
South_tf['HR90'].describe()
# Out:
# count    1412.000000
# mean        9.549293
# std         7.038851
# min         0.000000
# 25%         4.804794
# 50%         8.221220
# 75%        13.038023
# max        64.260999
# Name: HR90, dtype: float64

# %%
# %matplotlib inline
South_tf.plot(column='HR90', scheme='QUANTILES', k=10, \
             cmap='BuPu', legend=True, 
             legend_kwds={'loc': 'center left', 'bbox_to_anchor':(1,0.5)})

# %%
q10 = mapclassify.FisherJenks(South_tf.HR90, k=10)
q10
# Out:
# FisherJenks
#
#    Interval      Count
# ----------------------
# [ 0.00,  2.30] |   152
# ( 2.30,  5.79] |   309
# ( 5.79,  8.77] |   298
# ( 8.77, 12.03] |   250
# (12.03, 15.81] |   182
# (15.81, 20.21] |   109
# (20.21, 25.78] |    83
# (25.78, 33.10] |    18
# (33.10, 45.64] |     9
# (45.64, 64.26] |     2

# %%
mapclassify.BoxPlot(South_tf.HR90)
# Out:
# BoxPlot
#
#    Interval      Count
# ----------------------
# ( -inf, -7.55] |     0
# (-7.55,  4.80] |   353
# ( 4.80,  8.22] |   353
# ( 8.22, 13.04] |   353
# (13.04, 25.39] |   321
# (25.39, 64.26] |    32

# %%
South_tf.boxplot(column=['HR90'], grid=False)

# %%
South_tf.hist('HR90', bins=100, color = 'red')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd4170dcb90>]],
#       dtype=object)
